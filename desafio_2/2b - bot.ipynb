# %%
# Desafío #2: Bot de consulta abierta y respuesta predeterminada
# Luciano M. C. Smith

import string
import random 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader
import torchsummary
import spacy_stanza
import gradio as gr
import re
import unicodedata
import json
from torch_helpers import categorical_acc

# %% [markdown]
# ### Funciones para el trabajo con texto

# %%
# datos que necesitaremos, las palabras o vocabilario
words = []
classes = []
doc_X = []
doc_y = []

# cargo el archivo con el datasets de tags, patterns y respuestas
f = open("dict.json")
dataset = json.load(f)
f.close()

# carga diccionario en español
nlp = spacy_stanza.load_pipeline("es")

# funcion para limpieza de texto
def preprocess_clean_text(text):    
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')      # sacar tildes de las palabras
    pattern = r'[^a-zA-z0-9.,!?/:;\"\'\s]'                                                              # quitar caracteres especiales
    text = re.sub(pattern, '', text)
    pattern = r'[^a-zA-z.,!?/:;\"\'\s]' 
    text = re.sub(pattern, '', text)                                                                    # quitar números
    text = ''.join([c for c in text if c not in string.punctuation])                                    # quitar caracteres de puntiación
    return text

# Por cada intención (intents) debemos tomar los patrones que la caracterízan
# a esa intención y transformarla a tokens para lamacenar en doc_X
# El tag de cada intención se almacena como doc_Y (la clase a predecir)
for intent in dataset["intents"]:
    for pattern in intent["patterns"]:
        # trasformar el patron a tokens
        tokens = nlp(preprocess_clean_text(pattern.lower()))
        # lematizar los tokens
        for token in tokens:            
            words.append(token.lemma_)
        
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # Agregar el tag a las clases
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# Elminar duplicados con "set" y ordenar el vocubulario y las clases por orden alfabético
words = sorted(set(words))
classes = sorted(set(classes))

# Transformar doc_X en bag of words por oneHotEncoding
# Transformar doc_Y en un vector de clases multicategórico con oneHotEncoding

training = []
out_empty = [0] * len(classes)

for idx, doc in enumerate(doc_X):
    # Transformar la pregunta (input) en tokens y lematizar
    text = []
    tokens = nlp(preprocess_clean_text(doc.lower()))
    for token in tokens:
        text.append(token.lemma_)

    # Transformar los tokens en "Bag of words" (arrays de 1 y 0)
    bow = []
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    
    # Crear el array de salida (class output) correspondiente
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    training.append([bow, output_row])

# Mezclar los datos
random.shuffle(training)
training = np.array(training, dtype=object)
# Dividir en datos de entrada y salida
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

class Data(Dataset):
    def __init__(self, x, y):
        # Convertir los arrays de numpy a tensores. 
        # pytorch espera en general entradas 32bits
        self.x = torch.from_numpy(x.astype(np.float32))
        # las loss function esperan la salida float
        self.y = torch.from_numpy(y.astype(np.float32))

        self.len = self.y.shape[0]

    def __getitem__(self,index):
        return self.x[index], self.y[index]

    def __len__(self):
        return self.len

data_set = Data(train_X, train_y)
input_dim = data_set.x.shape[1]
output_dim = data_set.y.shape[1]

train_loader = DataLoader(data_set, batch_size=32, shuffle=False)
# Out:
# 2023-09-07 07:49:47 INFO: Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# =======================
#
# 2023-09-07 07:49:47 INFO: Use device: cpu
# 2023-09-07 07:49:47 INFO: Loading: tokenize
# 2023-09-07 07:49:47 INFO: Loading: mwt
# 2023-09-07 07:49:47 INFO: Loading: pos
# 2023-09-07 07:49:47 INFO: Loading: lemma
# 2023-09-07 07:49:47 INFO: Loading: depparse
# 2023-09-07 07:49:47 INFO: Loading: ner
# 2023-09-07 07:49:49 INFO: Done loading processors!

# %% [markdown]
# ### Creación y entrenamiento del modelo NN con PyTorch

# %%
# definicion de la arquitectura
class Model1(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.fc1 = nn.Linear(in_features=input_dim, out_features=128) # fully connected layer
        self.fc2 = nn.Linear(in_features=128, out_features=64) # fully connected layer
        self.fc3 = nn.Linear(in_features=64, out_features=output_dim) # fully connected layer
        
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1) # normalize in dim 1
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        out = self.relu(self.fc1(x))
        out = self.dropout(out)
        out = self.relu(self.fc2(out))
        out = self.dropout(out)
        out = self.softmax(self.fc3(out))
        return out

# Crear el modelo basado en la arquitectura definida
model1 = Model1(input_dim=input_dim, output_dim=output_dim)

# Crear el optimizador la una función de error
model1_optimizer = torch.optim.Adam(model1.parameters(), lr=0.001)
model1_criterion = torch.nn.CrossEntropyLoss()                          # Para clasificación multi categórica
torchsummary.summary(model1, input_size=(1, input_dim))

# funcion para entremamiento
def train(model, train_loader, optimizer, criterion, epochs=100):
    # Defino listas para realizar graficas de los resultados
    train_loss = []
    train_accuracy = []

    ## Defino mi loop de entrenamiento

    for epoch in range(epochs):

        epoch_train_loss = 0.0
        epoch_train_accuracy = 0.0

        for train_data, train_target in train_loader:

            # Seteo los gradientes en cero ya que, por defecto, PyTorch
            # los va acumulando
            optimizer.zero_grad()

            output = model(train_data)

            # Computo el error de la salida comparando contra las etiquetas
            loss = criterion(output, train_target)

            # Almaceno el error del batch para luego tener el error promedio de la epoca
            epoch_train_loss += loss.item()

            # Computo el nuevo set de gradientes a lo largo de toda la red
            loss.backward()

            # Realizo el paso de optimizacion actualizando los parametros de toda la red
            optimizer.step()
            
            # Calculo el accuracy del batch
            accuracy = categorical_acc(output, train_target)
            # Almaceno el accuracy del batch para luego tener el accuracy promedio de la epoca
            epoch_train_accuracy += accuracy.item()

        # Calculo la media de error y accuracy para la epoca de entrenamiento.
        # La longitud de train_loader es igual a la cantidad de batches dentro de una epoca.
        epoch_train_loss = epoch_train_loss / len(train_loader)
        train_loss.append(epoch_train_loss)
        epoch_train_accuracy = epoch_train_accuracy / len(train_loader)        
        train_accuracy.append(epoch_train_accuracy)

        print(f"Epoch: {epoch+1}/{epochs} - Train loss {epoch_train_loss:.3f} - Train accuracy {epoch_train_accuracy:.3f}")

    history = {
        "loss": train_loss,
        "accuracy": train_accuracy,
    }
    
    return history

# entrenamiento del modelo
history1 = train(model1, train_loader, model1_optimizer, model1_criterion, epochs=400)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 128]          11,520
#               ReLU-2               [-1, 1, 128]               0
#            Dropout-3               [-1, 1, 128]               0
#             Linear-4                [-1, 1, 64]           8,256
#               ReLU-5                [-1, 1, 64]               0
#            Dropout-6                [-1, 1, 64]               0
#             Linear-7                [-1, 1, 11]             715
#            Softmax-8                [-1, 1, 11]               0
# ================================================================
# Total params: 20,491
# Trainable params: 20,491
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.08
# Estimated Total Size (MB): 0.08
# ----------------------------------------------------------------
# Epoch: 1/400 - Train loss 2.397 - Train accuracy 0.080
# Epoch: 2/400 - Train loss 2.398 - Train accuracy 0.096
# Epoch: 3/400 - Train loss 2.398 - Train accuracy 0.112
# Epoch: 4/400 - Train loss 2.396 - Train accuracy 0.127
# Epoch: 5/400 - Train loss 2.396 - Train accuracy 0.175
# Epoch: 6/400 - Train loss 2.396 - Train accuracy 0.127
# Epoch: 7/400 - Train loss 2.395 - Train accuracy 0.128
# Epoch: 8/400 - Train loss 2.393 - Train accuracy 0.222
# Epoch: 9/400 - Train loss 2.394 - Train accuracy 0.191
# Epoch: 10/400 - Train loss 2.393 - Train accuracy 0.221
# Epoch: 11/400 - Train loss 2.392 - Train accuracy 0.222
# Epoch: 12/400 - Train loss 2.391 - Train accuracy 0.253
# Epoch: 13/400 - Train loss 2.389 - Train accuracy 0.333
# Epoch: 14/400 - Train loss 2.389 - Train accuracy 0.285
# Epoch: 15/400 - Train loss 2.390 - Train accuracy 0.220
# Epoch: 16/400 - Train loss 2.387 - Train accuracy 0.253
# Epoch: 17/400 - Train loss 2.385 - Train accuracy 0.300
# Epoch: 18/400 - Train loss 2.383 - Train accuracy 0.317
# Epoch: 19/400 - Train loss 2.384 - Train accuracy 0.301
# Epoch: 20/400 - Train loss 2.383 - Train accuracy 0.222
# Epoch: 21/400 - Train loss 2.378 - Train accuracy 0.316
# Epoch: 22/400 - Train loss 2.375 - Train accuracy 0.301
# Epoch: 23/400 - Train loss 2.373 - Train accuracy 0.285
# Epoch: 24/400 - Train loss 2.373 - Train accuracy 0.253
# Epoch: 25/400 - Train loss 2.367 - Train accuracy 0.285
# Epoch: 26/400 - Train loss 2.368 - Train accuracy 0.237
# Epoch: 27/400 - Train loss 2.360 - Train accuracy 0.253
# Epoch: 28/400 - Train loss 2.350 - Train accuracy 0.269
# Epoch: 29/400 - Train loss 2.348 - Train accuracy 0.284
# Epoch: 30/400 - Train loss 2.337 - Train accuracy 0.269
# Epoch: 31/400 - Train loss 2.332 - Train accuracy 0.237
# Epoch: 32/400 - Train loss 2.328 - Train accuracy 0.285
# Epoch: 33/400 - Train loss 2.320 - Train accuracy 0.237
# Epoch: 34/400 - Train loss 2.295 - Train accuracy 0.253
# Epoch: 35/400 - Train loss 2.292 - Train accuracy 0.253
# Epoch: 36/400 - Train loss 2.275 - Train accuracy 0.270
# Epoch: 37/400 - Train loss 2.288 - Train accuracy 0.254
# Epoch: 38/400 - Train loss 2.272 - Train accuracy 0.285
# Epoch: 39/400 - Train loss 2.252 - Train accuracy 0.301
# Epoch: 40/400 - Train loss 2.242 - Train accuracy 0.269
# Epoch: 41/400 - Train loss 2.236 - Train accuracy 0.333
# Epoch: 42/400 - Train loss 2.251 - Train accuracy 0.253
# Epoch: 43/400 - Train loss 2.232 - Train accuracy 0.333
# Epoch: 44/400 - Train loss 2.234 - Train accuracy 0.333
# Epoch: 45/400 - Train loss 2.208 - Train accuracy 0.445
# Epoch: 46/400 - Train loss 2.206 - Train accuracy 0.363
# Epoch: 47/400 - Train loss 2.181 - Train accuracy 0.412
# Epoch: 48/400 - Train loss 2.164 - Train accuracy 0.459
# Epoch: 49/400 - Train loss 2.177 - Train accuracy 0.476
# Epoch: 50/400 - Train loss 2.169 - Train accuracy 0.491
# Epoch: 51/400 - Train loss 2.144 - Train accuracy 0.476
# Epoch: 52/400 - Train loss 2.144 - Train accuracy 0.508
# Epoch: 53/400 - Train loss 2.130 - Train accuracy 0.508
# Epoch: 54/400 - Train loss 2.110 - Train accuracy 0.444
# Epoch: 55/400 - Train loss 2.134 - Train accuracy 0.524
# Epoch: 56/400 - Train loss 2.099 - Train accuracy 0.508
# Epoch: 57/400 - Train loss 2.110 - Train accuracy 0.539
# Epoch: 58/400 - Train loss 2.092 - Train accuracy 0.539
# Epoch: 59/400 - Train loss 2.092 - Train accuracy 0.539
# Epoch: 60/400 - Train loss 2.097 - Train accuracy 0.539
# Epoch: 61/400 - Train loss 2.065 - Train accuracy 0.523
# Epoch: 62/400 - Train loss 2.058 - Train accuracy 0.540
# Epoch: 63/400 - Train loss 2.026 - Train accuracy 0.571
# Epoch: 64/400 - Train loss 2.056 - Train accuracy 0.586
# Epoch: 65/400 - Train loss 2.011 - Train accuracy 0.571
# Epoch: 66/400 - Train loss 2.013 - Train accuracy 0.603
# Epoch: 67/400 - Train loss 1.996 - Train accuracy 0.635
# Epoch: 68/400 - Train loss 2.005 - Train accuracy 0.619
# Epoch: 69/400 - Train loss 1.990 - Train accuracy 0.635
# Epoch: 70/400 - Train loss 1.984 - Train accuracy 0.667
# Epoch: 71/400 - Train loss 1.985 - Train accuracy 0.666
# Epoch: 72/400 - Train loss 1.973 - Train accuracy 0.635
# Epoch: 73/400 - Train loss 1.965 - Train accuracy 0.651
# Epoch: 74/400 - Train loss 1.942 - Train accuracy 0.714
# Epoch: 75/400 - Train loss 1.913 - Train accuracy 0.730
# Epoch: 76/400 - Train loss 1.938 - Train accuracy 0.682
# Epoch: 77/400 - Train loss 1.912 - Train accuracy 0.730
# Epoch: 78/400 - Train loss 1.921 - Train accuracy 0.681
# Epoch: 79/400 - Train loss 1.922 - Train accuracy 0.698
# Epoch: 80/400 - Train loss 1.908 - Train accuracy 0.729
# Epoch: 81/400 - Train loss 1.871 - Train accuracy 0.761
# Epoch: 82/400 - Train loss 1.873 - Train accuracy 0.745
# Epoch: 83/400 - Train loss 1.884 - Train accuracy 0.777
# Epoch: 84/400 - Train loss 1.880 - Train accuracy 0.745
# Epoch: 85/400 - Train loss 1.831 - Train accuracy 0.761
# Epoch: 86/400 - Train loss 1.827 - Train accuracy 0.777
# Epoch: 87/400 - Train loss 1.848 - Train accuracy 0.762
# Epoch: 88/400 - Train loss 1.836 - Train accuracy 0.777
# Epoch: 89/400 - Train loss 1.877 - Train accuracy 0.745
# Epoch: 90/400 - Train loss 1.837 - Train accuracy 0.761
# Epoch: 91/400 - Train loss 1.893 - Train accuracy 0.713
# Epoch: 92/400 - Train loss 1.835 - Train accuracy 0.777
# Epoch: 376/400 - Train loss 1.552 - Train accuracy 1.000
# Epoch: 377/400 - Train loss 1.558 - Train accuracy 1.000
# Epoch: 378/400 - Train loss 1.550 - Train accuracy 1.000
# Epoch: 379/400 - Train loss 1.554 - Train accuracy 1.000
# Epoch: 380/400 - Train loss 1.565 - Train accuracy 1.000
# Epoch: 381/400 - Train loss 1.552 - Train accuracy 1.000
# Epoch: 382/400 - Train loss 1.568 - Train accuracy 0.969
# Epoch: 383/400 - Train loss 1.562 - Train accuracy 1.000
# Epoch: 384/400 - Train loss 1.557 - Train accuracy 1.000
# Epoch: 385/400 - Train loss 1.561 - Train accuracy 0.984
# Epoch: 386/400 - Train loss 1.549 - Train accuracy 1.000
# Epoch: 387/400 - Train loss 1.568 - Train accuracy 0.984
# Epoch: 388/400 - Train loss 1.550 - Train accuracy 1.000
# Epoch: 389/400 - Train loss 1.556 - Train accuracy 0.984
# Epoch: 390/400 - Train loss 1.552 - Train accuracy 1.000
# Epoch: 391/400 - Train loss 1.552 - Train accuracy 1.000
# Epoch: 392/400 - Train loss 1.559 - Train accuracy 1.000
# Epoch: 393/400 - Train loss 1.547 - Train accuracy 1.000
# Epoch: 394/400 - Train loss 1.557 - Train accuracy 1.000
# Epoch: 395/400 - Train loss 1.548 - Train accuracy 1.000
# Epoch: 396/400 - Train loss 1.556 - Train accuracy 1.000
# Epoch: 397/400 - Train loss 1.547 - Train accuracy 1.000
# Epoch: 398/400 - Train loss 1.556 - Train accuracy 1.000
# Epoch: 399/400 - Train loss 1.547 - Train accuracy 1.000
# Epoch: 400/400 - Train loss 1.558 - Train accuracy 1.000

# %% [markdown]
# ### Funciones para le preocesamiento de la pregunta

# %%
# tokenizacion del texto
def text_to_tokens(text): 
    lemma_tokens = []
    tokens = nlp(preprocess_clean_text(text.lower()))
    for token in tokens:
        lemma_tokens.append(token.lemma_)
    return lemma_tokens

def bag_of_words(text, vocab): 
    tokens = text_to_tokens(text)
    bow = [0] * len(vocab)
    for w in tokens: 
        for idx, word in enumerate(vocab):
            if word == w: 
                bow[idx] = 1
    return np.array(bow)

# predice el tag
def pred_class(text, vocab, labels): 
    bow = bag_of_words(text, vocab)
    words_recognized = sum(bow)

    return_list = []
    if words_recognized > 0:
        x = torch.from_numpy(np.array([bow]).astype(np.float32))
        result = model1(x)[0].detach().numpy()
        thresh = 0.2
        y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]
        y_pred.sort(key=lambda x: x[1], reverse=True)

        for r in y_pred:
            return_list.append(labels[r[0]])
            
    return return_list

# busca la respuesta
def get_response(intents_list, intents_json):
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents: 
        if i["tag"] == tag:
            result = random.choice(i["responses"])
            break
    return result

# funcion que devuelve una respuesta
def generate_response(message, history):
    intents = pred_class(message, words, classes)
    if len(intents) > 0:
        result = get_response(intents, dataset)
        
    else:
        result = "Perdón, no comprendo la pregunta."
    return result

# %% [markdown]
# ### Configuracion e lanzamiento del chat

# %%
demo = gr.ChatInterface(generate_response)
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
